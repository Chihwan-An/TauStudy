# %%
from importlib import import_module
import os
import sys
import argparse
import linecache
import uproot
import vector
import math
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
from tqdm import tqdm  # ✅ 진행률 표시
import glob
import json
vector.register_awkward()


## HLT 를 먼저 통과 한 이벤트 , hlthps tau 0개 이상인 이벤트만 -> 남은 이벤트 중에서 gen match -> genmatch 가 된 hlthps 의 이벤트를 남겨 놓음  



def get_info (sample):
    file = uproot.open(sample)
    events = file["Events"]
    runs = file["Runs"]
    keys = events.keys()

    # 변수 불러오기 

    tau_pt = events["hltHpsPFTau_pt"].array()
    tau_eta = events["hltHpsPFTau_eta"].array()
    tau_phi = events["hltHpsPFTau_phi"].array()
    tau_mass = events["hltHpsPFTau_mass"].array()


    genvis_tau_pt = events["GenVisTau_pt"].array()
    genvis_tau_eta = events["GenVisTau_eta"].array()
    genvis_tau_phi = events["GenVisTau_phi"].array()
    genvis_tau_mass = events["GenVisTau_mass"].array()
    #print(len(genvis_tau_pt),"gen vis tau total events")

    # 필터 설정

    ## trigger filter ( returns_num_den 에서 사용됨  )
    tau_trigger_filter = events["HLT_LooseDeepTauPFTauHPS180_L2NN_eta2p1"].array()

    ## hlthpstau 1개 이상 필터 

    tau_num = ak.num(tau_pt)
    no_tau = (tau_num == 0) # [ False, True, False, ... ] 2000개 
    has_tau = ~no_tau
    hlt_has_tau_filter = (has_tau) ## hlthps tau 1개 이상 있는 이벤트만 선택

    tau_triggerd_list= (hlt_has_tau_filter==True)  
    
    ## final selected variables ( hlthps 있는 이벤트만 남김 )
    final_tau_pt = tau_pt[tau_triggerd_list]
    final_tau_eta = tau_eta[tau_triggerd_list]
    final_tau_phi = tau_phi[tau_triggerd_list]
    final_tau_mass = tau_mass[tau_triggerd_list]

    final_genvis_tau_pt = genvis_tau_pt[tau_triggerd_list]
    final_genvis_tau_eta = genvis_tau_eta[tau_triggerd_list]
    final_genvis_tau_phi = genvis_tau_phi[tau_triggerd_list]
    final_genvis_tau_mass = genvis_tau_mass[tau_triggerd_list]

    tau_trigger_filtered = tau_trigger_filter[tau_triggerd_list]


    reco_tau_filter = final_tau_pt > 0  #  reco 0 이하인 이벤트,입자들 버리기
    gen_tau_filter = final_tau_pt > 0  ## reco 0 이하인 이벤트 버리기 

    final_tau_pt = final_tau_pt[reco_tau_filter]
    final_tau_eta = final_tau_eta[reco_tau_filter]
    final_tau_phi = final_tau_phi[reco_tau_filter]
    final_tau_mass = final_tau_mass[reco_tau_filter]


    print((final_tau_pt))
    print((final_genvis_tau_pt))
    total_events = len(tau_pt)
    print("total events:", total_events,"->","after trigger filter:",ak.sum(has_tau),"->","after reconstructed hlthps ,events remain",len(final_tau_pt))
    return events,final_tau_pt, final_tau_eta, final_tau_phi, final_tau_mass, final_genvis_tau_pt, final_genvis_tau_eta, final_genvis_tau_phi, final_genvis_tau_mass ,genvis_tau_pt , genvis_tau_eta , genvis_tau_phi ,tau_trigger_filtered


def deltaR(eta1,phi1,eta2,phi2):
    delta_eta = eta1 - eta2
    delta_phi = phi1 - phi2
    delta_phi = (delta_phi + math.pi) % (2 * math.pi) - math.pi
    return np.sqrt(delta_eta**2 + delta_phi**2)

def gen_match(tau_pt, tau_eta, tau_phi, genvis_tau_pt, genvis_tau_eta, genvis_tau_phi, deltaR_threshold=0.3,delta_pt_threshold=10):
    matched = [] ## gen 이벤트 인덱스 안에 들어있는 각 gen 입자의 매칭 여부 리스트 [[ True(event1 1 particle), False(event1 2 particle), ... ](event1), [ False, False, ... ](event2), ... ]
    events_flag = [] ## gen match 된 이벤트인지 아닌지 gen 이벤트의 bool 리스트 [ True(event1), False(event2), ... ]
    reco_matched = [] ## reco 이벤트 인덱스 안에 들어있는 각 reco 입자의 매칭 여부 리스트
    leading_matched = []
    subleading_matched = []
    both_matched = []

    for i in range(len(genvis_tau_pt)):# 전체 이벤트 갯수 반복 ( gen 이벤트 수와 동일해야 하므로 reco 로 디버그 차  설정 )
        genvis_tau_pt_i = genvis_tau_pt[i]
        genvis_tau_eta_i = genvis_tau_eta[i]
        genvis_tau_phi_i = genvis_tau_phi[i]
        tau_pt_i = tau_pt[i]
        tau_eta_i = tau_eta[i]
        tau_phi_i = tau_phi[i]
        match_flags = [] # matched 안에 넣기 위한 한 이벤트 의 매칭 여부 리스트 ( 각 입자의 매칭 여부가 여기에 저장 )
        has_genmatch = False
        leading_match = False
        subleading_match = False
        reco_match_flag = []
        for j in range(len(genvis_tau_pt_i)):
            genvis_tau_pt_ik = genvis_tau_pt_i[j]
            genvis_tau_eta_ik = genvis_tau_eta_i[j]
            genvis_tau_phi_ik = genvis_tau_phi_i[j]
            is_matched = False
            
            for k in range(len(tau_pt_i)):
                tau_pt_ij = tau_pt_i[k]
                tau_eta_ij = tau_eta_i[k]
                tau_phi_ij = tau_phi_i[k]
                recomatch = False
                if (abs(tau_eta_i[k]) > 2.1):
                    reco_match_flag.append(recomatch)
                    continue
                tau_pt_ij = tau_pt_i[k]
                tau_eta_ij = tau_eta_i[k]
                tau_phi_ij = tau_phi_i[k]
                
                dR = deltaR(tau_eta_ij, tau_phi_ij, genvis_tau_eta_ik, genvis_tau_phi_ik)
                dpt = abs(tau_pt_ij - genvis_tau_pt_ik)
                
                if dR < deltaR_threshold and dpt < delta_pt_threshold :
                    is_matched = True
                    has_genmatch = True
                    reco_match_flag.append(True)
                    if k == 0:
                        leading_match = True
                    elif k == 1:
                        subleading_match = True
                    break # 각 gen이 reco 중 하나라도 매칭되면 루프 탈출
                reco_match_flag.append(recomatch)

            match_flags.append(is_matched) # gen 입자당 루프 돌면서 해당 입자가 매칭 되었는지 저장 
        if has_genmatch:
            events_flag.append(True) # 이벤트 자체가 매칭된 이벤트인지 저장 
        else:
            events_flag.append(False)
        matched.append(np.array(match_flags)) ## 이벤트 당 match_flags(입자가 매칭됐는지를 리스트형태로 저장 )
        reco_matched.append(np.array(reco_match_flag))


        if leading_match :
            if subleading_match :
                both_matched.append(True)
                leading_matched.append(False)
                subleading_matched.append(False)
            if not subleading_match :
                leading_matched.append(True)
                subleading_matched.append(False)
                both_matched.append(False)

        if not leading_match :
            if subleading_match :
                subleading_matched.append(True)
                leading_matched.append(False)
                both_matched.append(False)
            else :
                subleading_matched.append(False)
                leading_matched.append(False)
                both_matched.append(False)


    return both_matched,leading_matched , subleading_matched , matched ,events_flag , reco_matched


#sample = "/gv0/Users/achihwan/phase2/cmssw_16/condor/hltrun/step2_fullstack_180.root"
#events_180,final_tau_pt_180, final_tau_eta_180, final_tau_phi_180, final_tau_mass_180, final_genvis_tau_pt_180, final_genvis_tau_eta_180, final_genvis_tau_phi_180, final_genvis_tau_mass_180 ,genvis_tau_pt_180 , genvis_tau_eta_180, genvis_tau_phi_180,tau_trigger_filter_180= get_info(sample)
#both_matched_180, leading_only_matched_180 , subleading_only_matched_180,gen_matched_180,events_flag_180 = gen_match(final_tau_pt_180, final_tau_eta_180, final_tau_phi_180, final_genvis_tau_pt_180, final_genvis_tau_eta_180, final_genvis_tau_phi_180)


sample = "/gv0/Users/achihwan/phase2/cmssw_16/condor/hltrun/step2_fullstack_150.root"
events_150,final_tau_pt_150, final_tau_eta_150, final_tau_phi_150, final_tau_mass_150, final_genvis_tau_pt_150, final_genvis_tau_eta_150, final_genvis_tau_phi_150, final_genvis_tau_mass_150,genvis_tau_pt_150 , genvis_tau_eta_150, genvis_tau_phi_150,tau_trigger_filter_150 = get_info(sample)
both_matched_150, leading_only_matched_150 , subleading_only_matched_150,gen_matched_150,events_flag_150 , reco_matched_150= gen_match(final_tau_pt_150, final_tau_eta_150, final_tau_phi_150, final_genvis_tau_pt_150, final_genvis_tau_eta_150, final_genvis_tau_phi_150)
# Out:
# [[252, 23.9, 13.4, 10.7, 8.15, 8.21, ..., 1.41, 1.39, 1.28, 0.973, 0.917], ...]
# [[231], [153, 32.4], [138], [219], [...], ..., [242], [89, 60.8], [92.2], [226]]
# total events: 15000 -> after trigger filter: 9516 -> after reconstructed hlthps ,events remain 9516

# %%
print((reco_matched_150[3]))
# Out:
# [ True]

# %% [markdown]
# gen plot ( Z' 's  tau eff )

# %%
import cmsstyle as CMS
import mplhep as hep
import matplotlib.pyplot as plt

## 리딩 서브리딩 아무거나 매칭 된 경우 
def returns_num_den (gen_matched, events_flag, final_tau_pt, final_tau_eta, final_tau_phi, final_genvis_tau_pt, final_genvis_tau_eta, final_genvis_tau_phi, genvis_tau_pt, genvis_tau_eta, genvis_tau_phi,tau_trigger_filter):
    #print(final_genvis_tau_pt)
    #print(len(final_genvis_tau_pt))
    gen_matched = ak.Array(gen_matched) ## 매치된 hlthpspftau 필터 
    #print(gen_matched)
    #print(len(gen_matched))
    genmatched_flags = gen_matched[events_flag] ## 매치된 이벤트중에 매치된 입자들 
    print("after gen match , events remain:",len(genmatched_flags))
    #print(final_genvis_tau_pt[gen_matched])
    #print(len(final_genvis_tau_pt[gen_matched]))
    match_genvistau_pt = final_genvis_tau_pt[gen_matched] # 매치된 이벤트만  살리는 필터 적용 
    #match_genvistau_pt = ak.sort(match_genvistau_pt, ascending=False)
    match_genvistau_eta = final_genvis_tau_eta[gen_matched]
    match_genvistau_phi = final_genvis_tau_phi[gen_matched]


    match_trigger_filter = gen_matched & tau_trigger_filter #& using_eta

    triggered_genvistau_pt = final_genvis_tau_pt[match_trigger_filter]
    #triggered_genvistau_pt = ak.sort(triggered_genvistau_pt, ascending=False)
    triggered_genvistau_eta = final_genvis_tau_eta[match_trigger_filter]
    triggered_genvistau_phi = final_genvis_tau_phi[match_trigger_filter]

    num_pt = triggered_genvistau_pt
    num_eta = triggered_genvistau_eta
    num_phi = triggered_genvistau_phi
    ## denominator ( 모든 genvistau 정보 )
    den_pt = match_genvistau_pt
    den_eta = match_genvistau_eta
    den_phi = match_genvistau_phi

    reco_tau_pt = final_tau_pt[match_trigger_filter]
    reco_tau_eta = final_tau_eta[match_trigger_filter]

    return num_pt, den_pt, num_eta, den_eta, num_phi, den_phi , reco_tau_pt ,reco_tau_eta
num_pt_150 , den_pt_150, num_eta_150, den_eta_150, num_phi_150, den_phi_150,reco_tau_pt_150 ,reco_tau_eta_150= returns_num_den (gen_matched_150, events_flag_150, final_tau_pt_150, final_tau_eta_150, final_tau_phi_150, final_genvis_tau_pt_150, final_genvis_tau_eta_150, final_genvis_tau_phi_150, genvis_tau_pt_150, genvis_tau_eta_150, genvis_tau_phi_150,tau_trigger_filter_150)
#pt 150 filter




# leading tau

num_pt_150 = ak.firsts(num_pt_150, axis=1)
not_none_num = ~ak.is_none(num_pt_150)
num_pt_150 = num_pt_150[not_none_num]

not_none_den = ~ak.is_none(den_pt_150)
den_pt_150 = den_pt_150[not_none_den]





########### pt efficiency plot ##############

bins_0 = np.arange(0, 180, 5)
bins_1 = np.arange(181, 300, 20)
bins_2 = np.arange(301, 601, 100)
bins = np.concatenate((bins_0, bins_1, bins_2))

num_pt_150 = ak.flatten(num_pt_150,axis=None)
den_pt_150 = ak.flatten(den_pt_150,axis=None)
num_pt_150 = num_pt_150.to_numpy()
den_pt_150 = den_pt_150.to_numpy()

counts_num_150, edges = np.histogram(num_pt_150, bins=bins)
counts_den_150, _ = np.histogram(den_pt_150, bins=bins)

ratio_150 = np.divide(counts_num_150, counts_den_150, 
                      out=np.zeros_like(counts_num_150, dtype=float), 
                      where=(counts_den_150 != 0))
ratio_err_150 = np.zeros_like(ratio_150)
nonzero_150 = counts_den_150 > 0
ratio_err_150[nonzero_150] = np.sqrt(ratio_150[nonzero_150] * (1.0 - ratio_150[nonzero_150]) / counts_den_150[nonzero_150])


# plot with error bars
bin_centers = (edges[:-1] + edges[1:]) / 2.0
half_widths = (edges[1:] - edges[:-1]) / 2.0

plt.style.use(hep.style.CMS)
fig, ax = plt.subplots(figsize=(10, 8))

# 두 데이터셋 그리기
ax.errorbar(bin_centers, ratio_150, xerr=half_widths, yerr=ratio_err_150, 
            fmt='o', color='C0', ecolor='C0', capsize=4, label='pT > 150 GeV')



ax.set_xlabel(r'Gen Tau $p_T$', fontsize=18)
ax.set_xlim(edges[0], edges[-1])
ax.set_ylim(0, 1.1)
ax.axvline(x=150, color='red', linestyle='--', linewidth=2, label='Trigger Threshold (150 GeV)')
ax.set_ylabel('Efficiency', fontsize=18)

# Legend 추가
ax.legend(loc='best', fontsize=14)

ax.grid(which='minor', linestyle=':', linewidth=0.5, alpha=0.5)

# CMS 스타일 레이블 추가
hep.cms.text("Simulation Preliminary", loc=4, ax=ax, fontsize=10)
ax.text(0.05, 0.9, r"$Z'(500GeV) \to \tau \tau$, PU=200",
    transform=ax.transAxes, fontsize=15, va='top', ha='left',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
ax.ticklabel_format(style="sci", scilimits=(-3, 3), useMathText=True)
ax.get_yaxis().get_offset_text().set_position((-0.085, 1.05))

plt.tight_layout()
plt.show()

################################################
## eta efficiency plot ##############

num_eta_150 = num_eta_150[not_none_num]
den_eta_150 = den_eta_150[not_none_den]

bins = np.arange(-2.5, 2.5, 0.1)

num_eta_150 = ak.flatten(num_eta_150,axis=None)
den_eta_150 = ak.flatten(den_eta_150,axis=None)
num_eta_150 = num_eta_150.to_numpy()
den_eta_150 = den_eta_150.to_numpy()

counts_num_150, edges = np.histogram(num_eta_150, bins=bins)
counts_den_150, _ = np.histogram(den_eta_150, bins=bins)

ratio_150 = np.divide(counts_num_150, counts_den_150, 
                      out=np.zeros_like(counts_num_150, dtype=float), 
                      where=(counts_den_150 != 0))
ratio_err_150 = np.zeros_like(ratio_150)
nonzero_150 = counts_den_150 > 0
ratio_err_150[nonzero_150] = np.sqrt(ratio_150[nonzero_150] * (1.0 - ratio_150[nonzero_150]) / counts_den_150[nonzero_150])


# plot with error bars
bin_centers = (edges[:-1] + edges[1:]) / 2.0
half_widths = (edges[1:] - edges[:-1]) / 2.0

plt.style.use(hep.style.CMS)
fig, ax = plt.subplots(figsize=(10, 8))

# 두 데이터셋 그리기
ax.errorbar(bin_centers, ratio_150, xerr=half_widths, yerr=ratio_err_150, 
            fmt='o', color='C0', ecolor='C0', capsize=4, label='pT > 150 GeV')



ax.set_xlabel(r'Gen Tau $\eta$', fontsize=18)
ax.set_xlim(edges[0], edges[-1])
ax.set_ylim(0, 1.3)

# Legend 추가
ax.legend(loc='best', fontsize=14)

ax.grid(which='minor', linestyle=':', linewidth=0.5, alpha=0.5)

# CMS 스타일 레이블 추가
hep.cms.text("Simulation Preliminary", loc=4, ax=ax, fontsize=10)
ax.text(0.05, 0.9, r"$Z'(500GeV) \to \tau \tau$, PU=200",
    transform=ax.transAxes, fontsize=15, va='top', ha='left',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
ax.ticklabel_format(style="sci", scilimits=(-3, 3), useMathText=True)
ax.get_yaxis().get_offset_text().set_position((-0.085, 1.05))

plt.tight_layout()
plt.show()







################################################
## phi  efficiency plot ##############
num_phi_150 = num_phi_150[not_none_num]
den_phi_150 = den_phi_150[not_none_den]

bins = np.arange(-3.2, 3.2, 0.1)

num_phi_150 = ak.flatten(num_phi_150,axis=None)
den_phi_150 = ak.flatten(den_phi_150,axis=None)
num_phi_150 = num_phi_150.to_numpy()
den_phi_150 = den_phi_150.to_numpy()

counts_num_150, edges = np.histogram(num_phi_150, bins=bins)
counts_den_150, _ = np.histogram(den_phi_150, bins=bins)

ratio_150 = np.divide(counts_num_150, counts_den_150, 
                      out=np.zeros_like(counts_num_150, dtype=float), 
                      where=(counts_den_150 != 0))
ratio_err_150 = np.zeros_like(ratio_150)
nonzero_150 = counts_den_150 > 0
ratio_err_150[nonzero_150] = np.sqrt(ratio_150[nonzero_150] * (1.0 - ratio_150[nonzero_150]) / counts_den_150[nonzero_150])


# plot with error bars
bin_centers = (edges[:-1] + edges[1:]) / 2.0
half_widths = (edges[1:] - edges[:-1]) / 2.0

plt.style.use(hep.style.CMS)
fig, ax = plt.subplots(figsize=(10, 8))

# 두 데이터셋 그리기
ax.errorbar(bin_centers, ratio_150, xerr=half_widths, yerr=ratio_err_150, 
            fmt='o', color='C0', ecolor='C0', capsize=4, label='pT > 150 GeV')



ax.set_xlabel(r'Gen Tau $\phi$', fontsize=18)
ax.set_xlim(edges[0], edges[-1])
ax.set_ylim(0, 1.3)


# Legend 추가
ax.legend(loc='best', fontsize=14)

ax.grid(which='minor', linestyle=':', linewidth=0.5, alpha=0.5)

# CMS 스타일 레이블 추가
hep.cms.text("Simulation Preliminary", loc=4, ax=ax, fontsize=10)
ax.text(0.05, 0.9, r"$Z'(500GeV) \to \tau \tau$, PU=200",
    transform=ax.transAxes, fontsize=15, va='top', ha='left',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
ax.ticklabel_format(style="sci", scilimits=(-3, 3), useMathText=True)
ax.get_yaxis().get_offset_text().set_position((-0.085, 1.05))

plt.tight_layout()
plt.show()


print(len(num_pt_150))
print(len(den_pt_150))
print("efficiency:" ,len(num_pt_150)/len(den_pt_150)*100,"%")
# Out:
# after gen match , events remain: 4848
# 2368
# 5633
# efficiency: 42.03799041363394 %

# %% [markdown]
# reco plot ( reco tau's plot  )

# %%
import cmsstyle as CMS
import mplhep as hep
import matplotlib.pyplot as plt

## 리딩 서브리딩 아무거나 매칭 된 경우 
def returns_num_den (reco_matched, events_flag, final_tau_pt, final_tau_eta, final_tau_phi, final_genvis_tau_pt, final_genvis_tau_eta, final_genvis_tau_phi, genvis_tau_pt, genvis_tau_eta, genvis_tau_phi,tau_trigger_filter):

    reco_matched = ak.Array(reco_matched) ## 매치된 hlthpspftau 필터 
    print("recomatch1",reco_matched)
    print(final_tau_pt)
    reco_matched = reco_matched[ak.local_index(reco_matched) < ak.num(final_tau_pt)]
    print("reco matched:",reco_matched)

    print("after gen match , events remain:",len(reco_matched))
    print(final_tau_pt[3])
    print(reco_matched[3])
    match_recotau_pt = final_tau_pt[reco_matched] # 매치된 이벤트만  살리는 필터 적용 
    match_recotau_eta = final_tau_eta[reco_matched]
    match_recotau_phi = final_tau_phi[reco_matched]

    match_trigger_filter = reco_matched & tau_trigger_filter #& using_eta

    triggered_recotau_pt = final_tau_pt[match_trigger_filter]
    triggered_recotau_eta = final_tau_eta[match_trigger_filter]
    triggered_recotau_phi = final_tau_phi[match_trigger_filter]

    num_pt = triggered_recotau_pt
    num_eta = triggered_recotau_eta
    num_phi = triggered_recotau_phi
    ## denominator ( 모든 genvistau 정보 )
    den_pt = match_recotau_pt
    den_eta = match_recotau_eta
    den_phi = match_recotau_phi

    reco_tau_pt = final_tau_pt[match_trigger_filter]
    reco_tau_eta = final_tau_eta[match_trigger_filter]

    return num_pt, den_pt, num_eta, den_eta, num_phi, den_phi , reco_tau_pt ,reco_tau_eta
num_pt_150 , den_pt_150, num_eta_150, den_eta_150, num_phi_150, den_phi_150,reco_tau_pt_150 ,reco_tau_eta_150= returns_num_den (reco_matched_150, events_flag_150, final_tau_pt_150, final_tau_eta_150, final_tau_phi_150, final_genvis_tau_pt_150, final_genvis_tau_eta_150, final_genvis_tau_phi_150, genvis_tau_pt_150, genvis_tau_eta_150, genvis_tau_phi_150,tau_trigger_filter_150)
#pt 150 filter
# Out:
# recomatch1 [[False], [], [], [True], [], [], ..., [True, False], [True], [], [False], []]
# [[252], [], [], [218], [], [], [], [], ..., [], [], [231], [238], [], [428], []]
# reco matched: [[False], [], [], [True], [], [], [], ..., [], [True], [True], [], [False], []]
# after gen match , events remain: 9516
# [218]
# [True]

# %%
print(len((ak.flatten(num_pt_150))))
print(len(ak.flatten(den_pt_150)))
print("efficiency:" ,len(ak.flatten(num_pt_150))/len(ak.flatten(den_pt_150))*100,"%")
# Out:
# 1684
# 1714
# efficiency: 98.24970828471412 %

# %%
num_pt_150 = ak.sort(num_pt_150, ascending=False)
print(num_pt_150[5])
num_pt_1501 = num_pt_150 [:,0]
den_pt_1501 = den_pt_150 [:,0]
num_eta_150 = num_eta_150 [:,0]
den_eta_150 = den_eta_150 [:,0]
num_phi_150 = num_phi_150 [:,0]
den_phi_150 = den_phi_150 [:,0]
reco_tau_pt_150 = ak.sort(reco_tau_pt_150, ascending=False)
print(reco_tau_pt_150[5])
print(reco_tau_pt_150[0])
reco_tau_pt_150 = reco_tau_pt_150[:,0]
reco_tau_eta_150 = reco_tau_eta_150[:,0]

den_eta_filter = (abs(den_eta_150) < 2.1)
num_eta_filter = (abs(num_eta_150) < 2.1)
reco_tau_eta_filter = (abs(num_eta_150) < 2.1)

num_pt_1501 = num_pt_1501 [num_eta_filter]
den_pt_1501 = den_pt_1501 [den_eta_filter]
reco_pt_1501 = reco_tau_pt_150[reco_tau_eta_filter]

low150 = (num_pt_1501 < 150)
print(np.where(low150)[0])
print(len(np.where(low150)[0]))
ptpt = num_pt_1501[3]
print(ptpt)


print(num_pt_1501[low150])
print(len(num_pt_1501[low150]))
plt.hist(num_pt_1501, bins=50, label='Triggered taus', alpha=0.7)
plt.hist(num_pt_1501[low150], bins=10, label='Triggered taus (pT < 150)', alpha=0.7)
plt.hist(ak.flatten(den_pt_150), bins=50, alpha=0.3, label='All matched taus')
plt.legend()
plt.xlabel('Gen Tau $p_T$', fontsize=12)
plt.ylabel('Events', fontsize=12)

plt.show()


reco_low_150 = (reco_pt_1501 < 150)


plt.hist(reco_pt_1501, bins=100, label='gen matched hlthpstaus', alpha=0.7)
#plt.hist(reco_pt_1501[reco_low_150], bins=50, label='reconstructed taus (pT < 150)', alpha=0.7)
plt.xlim(0, 300)
plt.legend()
plt.xlabel('reco Tau $p_T$', fontsize=12)
plt.ylabel('Events', fontsize=12)

plt.show()
print(num_pt_1501)
print(reco_pt_1501)
print(len(num_pt_1501))
print(len(reco_pt_1501))
# Out:
# 400.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/miniconda3/envs/hep-py-env/lib/python3.9/site-packages/awkward/contents/numpyarray.py:399, in NumpyArray._getitem_next(self, head, tail, advanced)
#     398 try:
# --> 399     out = self._data[where]
#     400 except IndexError as err:
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Cell In[120], line 3
#       1 num_pt_150 = ak.sort(num_pt_150, ascending=False)
#       2 print(num_pt_150[5])
# ----> 3 num_pt_1501 = num_pt_150 [:,0]
#       4 den_pt_1501 = den_pt_150 [:,0]
#       5 num_eta_150 = num_eta_150 [:,0]
#
# ...

# %% [markdown]
# ## Choosing only leading recotau

# %%
from importlib import import_module
import os
import sys
import argparse
import linecache
import uproot
import vector
import math
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
from tqdm import tqdm  # ✅ 진행률 표시
import glob
import json
vector.register_awkward()


## HLT 를 먼저 통과 한 이벤트 , hlthps tau 0개 이상인 이벤트만 -> 남은 이벤트 중에서 gen match -> genmatch 가 된 hlthps 의 이벤트를 남겨 놓음  



def get_info (sample):
    file = uproot.open(sample)
    events = file["Events"]
    runs = file["Runs"]
    keys = events.keys()

    # 변수 불러오기 

    tau_pt = events["hltHpsPFTau_pt"].array()
    tau_eta = events["hltHpsPFTau_eta"].array()
    tau_phi = events["hltHpsPFTau_phi"].array()
    tau_mass = events["hltHpsPFTau_mass"].array()


    genvis_tau_pt = events["GenVisTau_pt"].array()
    genvis_tau_eta = events["GenVisTau_eta"].array()
    genvis_tau_phi = events["GenVisTau_phi"].array()
    genvis_tau_mass = events["GenVisTau_mass"].array()
    #print(len(genvis_tau_pt),"gen vis tau total events")

    # 필터 설정

    ## trigger filter ( returns_num_den 에서 사용됨  )
    tau_trigger_filter = events["HLT_LooseDeepTauPFTauHPS180_L2NN_eta2p1"].array()

    ## hlthpstau 1개 이상 필터 

    tau_num = ak.num(tau_pt)
    no_tau = (tau_num == 0) # [ False, True, False, ... ] 2000개 
    has_tau = ~no_tau
    hlt_has_tau_filter = (has_tau) ## hlthps tau 1개 이상 있는 이벤트만 선택

    tau_triggerd_list= (hlt_has_tau_filter==True)  
    
    ## final selected variables ( hlthps 있는 이벤트만 남김 )
    final_tau_pt = tau_pt[tau_triggerd_list]
    final_tau_eta = tau_eta[tau_triggerd_list]
    final_tau_phi = tau_phi[tau_triggerd_list]
    final_tau_mass = tau_mass[tau_triggerd_list]

    final_genvis_tau_pt = genvis_tau_pt[tau_triggerd_list]
    final_genvis_tau_eta = genvis_tau_eta[tau_triggerd_list]
    final_genvis_tau_phi = genvis_tau_phi[tau_triggerd_list]
    final_genvis_tau_mass = genvis_tau_mass[tau_triggerd_list]

    tau_trigger_filtered = tau_trigger_filter[tau_triggerd_list]



    print((final_tau_pt))
    print((final_genvis_tau_pt))
    total_events = len(tau_pt)
    print("total events:", total_events,"->","after trigger filter:",ak.sum(has_tau),"->","after reconstructed hlthps ,events remain",len(final_tau_pt))
    return events,final_tau_pt, final_tau_eta, final_tau_phi, final_tau_mass, final_genvis_tau_pt, final_genvis_tau_eta, final_genvis_tau_phi, final_genvis_tau_mass ,genvis_tau_pt , genvis_tau_eta , genvis_tau_phi ,tau_trigger_filtered


def deltaR(eta1,phi1,eta2,phi2):
    delta_eta = eta1 - eta2
    delta_phi = phi1 - phi2
    delta_phi = (delta_phi + math.pi) % (2 * math.pi) - math.pi
    return np.sqrt(delta_eta**2 + delta_phi**2)

def gen_match(tau_pt, tau_eta, tau_phi, genvis_tau_pt, genvis_tau_eta, genvis_tau_phi, deltaR_threshold=0.3,delta_pt_threshold=10):
    matched = [] ## gen 이벤트 인덱스 안에 들어있는 각 gen 입자의 매칭 여부 리스트 [[ True(event1 1 particle), False(event1 2 particle), ... ](event1), [ False, False, ... ](event2), ... ]
    events_flag = [] ## gen match 된 이벤트인지 아닌지 gen 이벤트의 bool 리스트 [ True(event1), False(event2), ... ]
    reco_matched = [] ## reco 이벤트 인덱스 안에 들어있는 각 reco 입자의 매칭 여부 리스트
    leading_matched = []
    subleading_matched = []
    both_matched = []

    for i in range(len(genvis_tau_pt)):
        # 1. 정렬
        reco_indices = ak.argsort(tau_pt[i], ascending=False)
        t_pt, t_eta, t_phi = tau_pt[i][reco_indices], tau_eta[i][reco_indices], tau_phi[i][reco_indices]
        
        # 2. 이번 이벤트의 상태 초기화 (이벤트 루프 시작할 때마다 초기화해야 함)
        reco_match_flag = [False] * len(t_pt) 
        match_flags = []
        has_genmatch = False
        leading_match = False
        subleading_match = False

        # Gen 입자 루프
        for j in range(len(genvis_tau_pt[i])):
            g_pt, g_eta, g_phi = genvis_tau_pt[i][j], genvis_tau_eta[i][j], genvis_tau_phi[i][j]
            is_matched = False
            
            # 3. Leading Reco Tau(인덱스 0)와 매칭 시도
            if len(t_pt) > 0:
                # k 루프 대신 인덱스 0 사용 (Leading)
                if abs(t_eta[0]) <= 2.1:
                    dR = deltaR(t_eta[0], t_phi[0], g_eta, g_phi)
                    dpt = abs(t_pt[0] - g_pt)
                    
                    if dR < deltaR_threshold and dpt < delta_pt_threshold:
                        is_matched = True
                        has_genmatch = True
                        reco_match_flag[0] = True # Leading 매칭 표시
                        leading_match = True      # 플래그 업데이트
                        # 만약 여기서 j(gen) 루프를 탈출하고 싶다면 break
            
            match_flags.append(is_matched)
        if has_genmatch:
            events_flag.append(True) # 이벤트 자체가 매칭된 이벤트인지 저장 
        else:
            events_flag.append(False)
        matched.append(np.array(match_flags)) ## 이벤트 당 match_flags(입자가 매칭됐는지를 리스트형태로 저장 )
        reco_matched.append(np.array(reco_match_flag))


    return both_matched,leading_matched , subleading_matched , matched ,events_flag , reco_matched


#sample = "/gv0/Users/achihwan/phase2/cmssw_16/condor/hltrun/step2_fullstack_180.root"
#events_180,final_tau_pt_180, final_tau_eta_180, final_tau_phi_180, final_tau_mass_180, final_genvis_tau_pt_180, final_genvis_tau_eta_180, final_genvis_tau_phi_180, final_genvis_tau_mass_180 ,genvis_tau_pt_180 , genvis_tau_eta_180, genvis_tau_phi_180,tau_trigger_filter_180= get_info(sample)
#both_matched_180, leading_only_matched_180 , subleading_only_matched_180,gen_matched_180,events_flag_180 = gen_match(final_tau_pt_180, final_tau_eta_180, final_tau_phi_180, final_genvis_tau_pt_180, final_genvis_tau_eta_180, final_genvis_tau_phi_180)


sample = "/gv0/Users/achihwan/phase2/cmssw_16/condor/hltrun/step2_fullstack_150.root"
events_150,final_tau_pt_150, final_tau_eta_150, final_tau_phi_150, final_tau_mass_150, final_genvis_tau_pt_150, final_genvis_tau_eta_150, final_genvis_tau_phi_150, final_genvis_tau_mass_150,genvis_tau_pt_150 , genvis_tau_eta_150, genvis_tau_phi_150,tau_trigger_filter_150 = get_info(sample)
both_matched_150, leading_only_matched_150 , subleading_only_matched_150,gen_matched_150,events_flag_150 , reco_matched_150= gen_match(final_tau_pt_150, final_tau_eta_150, final_tau_phi_150, final_genvis_tau_pt_150, final_genvis_tau_eta_150, final_genvis_tau_phi_150)
# Out:
# [[252, 23.9, 13.4, 10.7, 8.15, 8.21, ..., 1.41, 1.39, 1.28, 0.973, 0.917], ...]
# [[231], [153, 32.4], [138], [219], [...], ..., [242], [89, 60.8], [92.2], [226]]
# total events: 15000 -> after trigger filter: 9516 -> after reconstructed hlthps ,events remain 9516
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 142
#     140 sample = "/gv0/Users/achihwan/phase2/cmssw_16/condor/hltrun/step2_fullstack_150.root"
#     141 events_150,final_tau_pt_150, final_tau_eta_150, final_tau_phi_150, final_tau_mass_150, final_genvis_tau_pt_150, final_genvis_tau_eta_150, final_genvis_tau_phi_150, final_genvis_tau_mass_150,genvis_tau_pt_150 , genvis_tau_eta_150, genvis_tau_phi_150,tau_trigger_filter_150 = get_info(sample)
# ...

# %%
print(len(events_flag_150))
print(ak.sum(events_flag_150))
print(len(final_tau_pt_150))
print(len(final_genvis_tau_pt_150))
print(events_flag_150)
print(reco_matched_150[3])
print(final_tau_pt_150[3])
print(final_genvis_tau_pt_150[3])
reco_indices = ak.argsort(final_tau_pt_150, ascending=False)
print(final_tau_pt_150[reco_indices][3])
# Out:
# 9516
# 3572
# 9516
# 9516
# ...

# %%
import cmsstyle as CMS
import mplhep as hep
import matplotlib.pyplot as plt

## 리딩 서브리딩 아무거나 매칭 된 경우 
def returns_num_den (gen_matched, events_flag, final_tau_pt, final_tau_eta, final_tau_phi, final_genvis_tau_pt, final_genvis_tau_eta, final_genvis_tau_phi, genvis_tau_pt, genvis_tau_eta, genvis_tau_phi,tau_trigger_filter,reco_match):
    #print(final_genvis_tau_pt)
    #print(len(final_genvis_tau_pt))
    gen_matched = ak.Array(gen_matched) ## 매치된 hlthpspftau 필터 
    
    reco_match = ak.Array(reco_match)
    recomatched_flags = reco_match[events_flag]
    genmatched_flags = gen_matched[events_flag] ## 매치된 이벤트중에 매치된 입자들 
    print("after gen match , events remain:",len(genmatched_flags))
    #print(final_genvis_tau_pt[gen_matched])
    #print(len(final_genvis_tau_pt[gen_matched]))
    match_genvistau_pt = final_genvis_tau_pt[gen_matched] # 매치된 이벤트만  살리는 필터 적용 
    #match_genvistau_pt = ak.sort(match_genvistau_pt, ascending=False)
    match_genvistau_eta = final_genvis_tau_eta[gen_matched]
    match_genvistau_phi = final_genvis_tau_phi[gen_matched]

    reco_indices = ak.argsort(final_tau_pt, ascending=False)
    final_tau_pt = final_tau_pt[reco_indices]
    final_tau_eta = final_tau_eta[reco_indices]
    final_tau_phi = final_tau_phi[reco_indices] 

    match_recotau_pt = final_tau_pt[reco_match] # 매치된 이벤트만  살리는 필터 적용
    match_recotau_eta = final_tau_eta[reco_match]
    match_recotau_phi = final_tau_phi[reco_match]


    match_trigger_filter = gen_matched & tau_trigger_filter #& using_eta
    reco_match_trigger_filter = reco_match & tau_trigger_filter

    triggered_genvistau_pt = final_genvis_tau_pt[match_trigger_filter]
    #triggered_genvistau_pt = ak.sort(triggered_genvistau_pt, ascending=False)
    triggered_genvistau_eta = final_genvis_tau_eta[match_trigger_filter]
    triggered_genvistau_phi = final_genvis_tau_phi[match_trigger_filter]

    num_pt = triggered_genvistau_pt
    num_eta = triggered_genvistau_eta
    num_phi = triggered_genvistau_phi
    ## denominator ( 모든 genvistau 정보 )
    den_pt = match_genvistau_pt
    den_eta = match_genvistau_eta
    den_phi = match_genvistau_phi

    reco_tau_pt = final_tau_pt[reco_match_trigger_filter]
    reco_tau_eta = final_tau_eta[reco_match_trigger_filter]
    reco_tau_phi = final_tau_phi[reco_match_trigger_filter]

    return num_pt, den_pt, num_eta, den_eta, num_phi, den_phi , reco_tau_pt ,reco_tau_eta, reco_tau_phi, match_recotau_pt, match_recotau_eta, match_recotau_phi
num_pt_150 , den_pt_150, num_eta_150, den_eta_150, num_phi_150, den_phi_150,reco_tau_pt_150 ,reco_tau_eta_150,reco_tau_phi_150,match_recotau_pt_150, match_recotau_eta_150, match_recotau_phi_150= returns_num_den (gen_matched_150, events_flag_150, final_tau_pt_150, final_tau_eta_150, final_tau_phi_150, final_genvis_tau_pt_150, final_genvis_tau_eta_150, final_genvis_tau_phi_150, genvis_tau_pt_150, genvis_tau_eta_150, genvis_tau_phi_150,tau_trigger_filter_150,reco_matched_150)
#pt 150 filter
print(num_pt_150)
print(reco_tau_pt_150)



### pt plot 

# leading tau
num_pt_150 = ak.firsts(num_pt_150, axis=1)
pt_ov_150 = (num_pt_150 > 150)
not_none_num = ~ak.is_none(num_pt_150)
num_pt_150 = num_pt_150[not_none_num]
print(num_pt_150)

ov_150_and_not_none = pt_ov_150 & not_none_num

not_none_den = ak.num(den_pt_150) > 0
den_pt_150 = den_pt_150[not_none_den]

bins_0 = np.arange(0, 180, 5)
bins_1 = np.arange(181, 300, 20)
bins_2 = np.arange(301, 601, 100)
bins = np.concatenate((bins_0, bins_1, bins_2))

num_pt_150 = ak.flatten(num_pt_150, axis=None).to_numpy()
den_pt_150 = ak.flatten(den_pt_150, axis=None).to_numpy()

counts_num_150, edges = np.histogram(num_pt_150, bins=bins)
counts_den_150, _ = np.histogram(den_pt_150, bins=bins)

ratio_150 = np.divide(
    counts_num_150, counts_den_150,
    out=np.zeros_like(counts_num_150, dtype=float),
    where=(counts_den_150 != 0)
)
ratio_err_150 = np.zeros_like(ratio_150)
nonzero_150 = counts_den_150 > 0
ratio_err_150[nonzero_150] = np.sqrt(
    ratio_150[nonzero_150] * (1.0 - ratio_150[nonzero_150]) / counts_den_150[nonzero_150]
)

# reco tau efficiency (same bins)
match_recotau_pt_150 = ak.flatten(match_recotau_pt_150, axis=None).to_numpy()
reco_tau_pt_150 = ak.flatten(reco_tau_pt_150, axis=None).to_numpy()

counts_reco_num_150, _ = np.histogram(reco_tau_pt_150, bins=bins)
counts_reco_den_150, _ = np.histogram(match_recotau_pt_150, bins=bins)

ratio_reco_150 = np.divide(
    counts_reco_num_150, counts_reco_den_150,
    out=np.zeros_like(counts_reco_num_150, dtype=float),
    where=(counts_reco_den_150 != 0)
)
ratio_reco_err_150 = np.zeros_like(ratio_reco_150)
nonzero_reco_150 = counts_reco_den_150 > 0
ratio_reco_err_150[nonzero_reco_150] = np.sqrt(
    ratio_reco_150[nonzero_reco_150] * (1.0 - ratio_reco_150[nonzero_reco_150]) / counts_reco_den_150[nonzero_reco_150]
)

# plot (different color + marker shape)
bin_centers = (edges[:-1] + edges[1:]) / 2.0
half_widths = (edges[1:] - edges[:-1]) / 2.0

plt.style.use(hep.style.CMS)
fig, ax = plt.subplots(figsize=(10, 8))

ax.errorbar(
    bin_centers, ratio_150, xerr=half_widths, yerr=ratio_err_150,
    fmt='o', ms=6, color='tab:blue', ecolor='tab:blue', capsize=3,
    linestyle='none', label='Gen Tau (matched + trigger)'
)

ax.errorbar(
    bin_centers, ratio_reco_150, xerr=half_widths, yerr=ratio_reco_err_150,
    fmt='s', ms=5, color='tab:orange', ecolor='tab:orange', capsize=3,
    linestyle='none', label='Reco Tau (Gen matched) + Tiggered pass'
)

ax.set_xlabel(r'Gen Tau $p_T$', fontsize=18)
ax.set_ylabel('Efficiency', fontsize=18)
ax.set_xlim(edges[0], edges[-1])
ax.set_ylim(0, 1.1)
ax.axvline(x=150, color='red', linestyle='--', linewidth=2, label='Trigger Threshold (150 GeV)')
ax.legend(loc='best', fontsize=13)
ax.grid(which='minor', linestyle=':', linewidth=0.5, alpha=0.5)

hep.cms.text("Simulation Preliminary", loc=4, ax=ax, fontsize=10)
ax.text(
    0.05, 0.9, r"$Z'(500GeV) \to \tau \tau$, PU=200",
    transform=ax.transAxes, fontsize=15, va='top', ha='left',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='none')
)
ax.ticklabel_format(style="sci", scilimits=(-3, 3), useMathText=True)
ax.get_yaxis().get_offset_text().set_position((-0.085, 1.05))

plt.tight_layout()
plt.show()

num_pt_150_cut = num_pt_150[num_pt_150 > 150]
den_pt_150_cut = den_pt_150[den_pt_150 > 150]
print("Efficiency for Gen Tau pT > 150 GeV:", len(num_pt_150_cut) / len(den_pt_150_cut) * 100, "%")







## eta plot 


num_eta_150 = num_eta_150[ov_150_and_not_none]
den_eta_150 = den_eta_150[ov_150_and_not_none]
print(num_eta_150)
print(den_eta_150)




bins = np.arange(-2.5, 2.5, 0.1)
num_eta_150 = ak.flatten(num_eta_150,axis=None)
den_eta_150 = ak.flatten(den_eta_150,axis=None)
num_eta_150 = num_eta_150.to_numpy()
den_eta_150 = den_eta_150.to_numpy()
counts_num_150, edges = np.histogram(num_eta_150, bins=bins)
counts_den_150, _ = np.histogram(den_eta_150, bins=bins)
ratio_150 = np.divide(counts_num_150, counts_den_150, 
                      out=np.zeros_like(counts_num_150, dtype=float), 
                      where=(counts_den_150 != 0))
ratio_err_150 = np.zeros_like(ratio_150)
nonzero_150 = counts_den_150 > 0
ratio_err_150[nonzero_150] = np.sqrt(ratio_150[nonzero_150] * (1.0 - ratio_150[nonzero_150]) / counts_den_150[nonzero_150])

# plot with error bars
bin_centers = (edges[:-1] + edges[1:]) / 2.0
half_widths = (edges[1:] - edges[:-1]) / 2.0    
plt.style.use(hep.style.CMS)
fig, ax = plt.subplots(figsize=(10, 8))
# 두 데이터셋 그리기
ax.errorbar(bin_centers, ratio_150, xerr=half_widths, yerr=ratio_err_150, 
            fmt='o', color='C0', ecolor='C0', capsize=4, label='pT > 150 GeV')
ax.set_xlabel(r'Gen Tau $\eta$', fontsize=18)
ax.set_xlim(edges[0], edges[-1])
ax.set_ylim(0, 1.3)
# Legend 추가
ax.legend(loc='best', fontsize=14)
ax.grid(which='minor', linestyle=':', linewidth=0.5, alpha=0.5)
# CMS 스타일 레이블 추가
hep.cms.text("Simulation Preliminary", loc=4, ax=ax, fontsize=10)
ax.text(0.05, 0.9, r"$Z'(500GeV) \to \tau \tau$, PU=200",
    transform=ax.transAxes, fontsize=15, va='top', ha='left',
    bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
ax.ticklabel_format(style="sci", scilimits=(-3, 3), useMathText=True)
ax.get_yaxis().get_offset_text().set_position((-0.085, 1.05))
plt.tight_layout()
plt.show()
# Out:
# after gen match , events remain: 3572
# [[], [], [], [219], [], [], [], [], ..., [], [], [], [234], [242], [], [], []]
# [[], [], [], [218], [], [], [], [], ..., [], [], [], [231], [238], [], [], []]
# [219, 212, 218, 170, 165, 174, 152, 222, ..., 172, 154, 162, 224, 190, 234, 242]
# Efficiency for Gen Tau pT > 150 GeV: 96.83470105509964 %
# [None, None, None, [0.134], None, ..., [-0.76], [0.0845], None, None, None]
# [None, None, None, [0.134], None, ..., [-0.76], [0.0845], None, None, None]
