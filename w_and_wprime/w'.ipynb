# %%
from importlib import import_module
import os
import sys
import argparse
import linecache
import uproot
import vector
import math
import numpy as np
import matplotlib.pyplot as plt
import awkward as ak
from tqdm import tqdm  # ✅ 진행률 표시
import glob
import json
vector.register_awkward()
import cmsstyle as CMS
import mplhep as hep
import matplotlib.pyplot as plt
from collections import Counter
sample = "/gv0/Users/achihwan/phase2/cmssw_16/run3_wtau_wprime/wprime/primeToTauNu_M400/2540000/1a9f1462-4d16-4039-9180-ea2332aadfbb.root"
file = uproot.open(sample)
events = file["Events"]
runs = file["Runs"]
keys = events.keys()
